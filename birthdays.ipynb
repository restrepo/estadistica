# %%
import numpy as np
import collections
b=0
n=23
t=1000
for i in range(tr):
    x=np.random.randint(1,366,n)
    c=collections.Counter(x)
    r=sorted(c.values())[::-1][0]
    if r>1:
        b=b+1

print b
# Out:
# 515

# %%
# Out:
# 2
